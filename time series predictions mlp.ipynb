# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_series(time, series, start=0, end=None, format='-'):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel('Time')
    plt.ylabel('Series')
    plt.grid(True)

# %%
def trend(time, slope=0):
    return slope * time

# %%
def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

# %%
from random import randrange

def white_noise (time):
    series = np.random.randn(len(time))
    return series

# %%
time = np.arange(4 * 365 + 1, dtype="float32")

baseline = 10
slope = 0.03
amplitude = 2

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += white_noise(time)

plot_series (time, series)

# %%
split_point = 1000
window_size = 20
window_shift_size = 1
shuffle_buffer = 900
batch_size = 32

time_train = time[0:split_point]
series_train = series[0:split_point]

time_val = time[split_point:]
series_val = series[split_point:]

# %%
plot_series (time_train, series_train)

# %%
plot_series (time_val, series_val)

# %%
def windowed_dataset(series, window_size, shift_size, shuffle_buffer, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(size=window_size+1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size+1))
    dataset = dataset.map(lambda window: (window[:-1], window[-1:]))
    dataset = dataset.shuffle(buffer_size=shuffle_buffer)
    dataset = dataset.batch(batch_size=batch_size, drop_remainder=True).prefetch(1)
    return dataset

# %%
dataset = windowed_dataset(series_train, window_size, window_shift_size, shuffle_buffer, batch_size)

# %%
model = tf.keras.models.Sequential()
l1 = tf.keras.layers.Dense(50, input_shape=[window_size], activation='relu')
l2 = tf.keras.layers.Dense(1)
model.add(l1)
model.add(l2)
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6), loss='mse', metrics=['accuracy'])
model.summary()

model.fit(dataset, epochs=200, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 50)                1050
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 1,101
# Trainable params: 1,101
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 30/30 [==============================] - 1s 17ms/step - loss: 6.3969 - accuracy: 0.0000e+00
# Epoch 2/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.7589 - accuracy: 0.0000e+00
# Epoch 3/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5875 - accuracy: 0.0000e+00
# Epoch 4/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5817 - accuracy: 0.0000e+00
# Epoch 5/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5809 - accuracy: 0.0000e+00
# Epoch 6/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5801 - accuracy: 0.0000e+00
# Epoch 7/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5792 - accuracy: 0.0000e+00
# Epoch 8/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5782 - accuracy: 0.0000e+00
# Epoch 9/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5772 - accuracy: 0.0000e+00
# Epoch 10/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5763 - accuracy: 0.0000e+00
# Epoch 11/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5754 - accuracy: 0.0000e+00
# Epoch 12/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5745 - accuracy: 0.0000e+00
# Epoch 13/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5737 - accuracy: 0.0000e+00
# Epoch 14/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5730 - accuracy: 0.0000e+00
# Epoch 15/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5723 - accuracy: 0.0000e+00
# Epoch 16/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5716 - accuracy: 0.0000e+00
# Epoch 17/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5710 - accuracy: 0.0000e+00
# Epoch 18/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5704 - accuracy: 0.0000e+00
# Epoch 19/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5699 - accuracy: 0.0000e+00
# Epoch 20/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5694 - accuracy: 0.0000e+00
# Epoch 21/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5689 - accuracy: 0.0000e+00
# Epoch 22/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5684 - accuracy: 0.0000e+00
# Epoch 23/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5680 - accuracy: 0.0000e+00
# Epoch 24/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5676 - accuracy: 0.0000e+00
# Epoch 25/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5673 - accuracy: 0.0000e+00
# Epoch 26/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5669 - accuracy: 0.0000e+00
# Epoch 27/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5666 - accuracy: 0.0000e+00
# Epoch 28/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5662 - accuracy: 0.0000e+00
# Epoch 29/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5659 - accuracy: 0.0000e+00
# Epoch 30/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5656 - accuracy: 0.0000e+00
# Epoch 31/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5653 - accuracy: 0.0000e+00
# Epoch 32/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5649 - accuracy: 0.0000e+00
# Epoch 33/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5646 - accuracy: 0.0000e+00
# Epoch 34/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5642 - accuracy: 0.0000e+00
# Epoch 35/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5639 - accuracy: 0.0000e+00
# Epoch 36/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5636 - accuracy: 0.0000e+00
# Epoch 37/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5633 - accuracy: 0.0000e+00
# Epoch 38/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5629 - accuracy: 0.0000e+00
# Epoch 39/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5625 - accuracy: 0.0000e+00
# Epoch 40/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5622 - accuracy: 0.0000e+00
# Epoch 41/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5619 - accuracy: 0.0000e+00
# Epoch 42/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5616 - accuracy: 0.0000e+00
# Epoch 43/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5612 - accuracy: 0.0000e+00
# Epoch 44/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5609 - accuracy: 0.0000e+00
# Epoch 45/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5605 - accuracy: 0.0000e+00
# Epoch 46/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5602 - accuracy: 0.0000e+00
# Epoch 47/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5599 - accuracy: 0.0000e+00
# Epoch 48/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5596 - accuracy: 0.0000e+00
# Epoch 49/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5593 - accuracy: 0.0000e+00
# Epoch 50/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5591 - accuracy: 0.0000e+00
# Epoch 51/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5588 - accuracy: 0.0000e+00
# Epoch 52/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5586 - accuracy: 0.0000e+00
# Epoch 53/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5583 - accuracy: 0.0000e+00
# Epoch 54/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5581 - accuracy: 0.0000e+00
# Epoch 55/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5578 - accuracy: 0.0000e+00
# Epoch 56/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5576 - accuracy: 0.0000e+00
# Epoch 57/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5574 - accuracy: 0.0000e+00
# Epoch 58/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5572 - accuracy: 0.0000e+00
# Epoch 59/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5569 - accuracy: 0.0000e+00
# Epoch 60/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5567 - accuracy: 0.0000e+00
# Epoch 61/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5565 - accuracy: 0.0000e+00
# Epoch 62/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5563 - accuracy: 0.0000e+00
# Epoch 63/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5560 - accuracy: 0.0000e+00
# Epoch 64/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5558 - accuracy: 0.0000e+00
# Epoch 65/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5556 - accuracy: 0.0000e+00
# Epoch 66/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5554 - accuracy: 0.0000e+00
# Epoch 67/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5552 - accuracy: 0.0000e+00
# Epoch 68/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5550 - accuracy: 0.0000e+00
# Epoch 69/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5548 - accuracy: 0.0000e+00
# Epoch 70/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5546 - accuracy: 0.0000e+00
# Epoch 71/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5543 - accuracy: 0.0000e+00
# Epoch 72/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5541 - accuracy: 0.0000e+00
# Epoch 73/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5539 - accuracy: 0.0000e+00
# Epoch 74/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5537 - accuracy: 0.0000e+00
# Epoch 75/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5535 - accuracy: 0.0000e+00
# Epoch 76/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5533 - accuracy: 0.0000e+00
# Epoch 77/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5531 - accuracy: 0.0000e+00
# Epoch 78/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5529 - accuracy: 0.0000e+00
# Epoch 79/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5527 - accuracy: 0.0000e+00
# Epoch 80/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5525 - accuracy: 0.0000e+00
# Epoch 81/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5523 - accuracy: 0.0000e+00
# Epoch 82/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5521 - accuracy: 0.0000e+00
# Epoch 83/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5519 - accuracy: 0.0000e+00
# Epoch 84/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5517 - accuracy: 0.0000e+00
# Epoch 85/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5515 - accuracy: 0.0000e+00
# Epoch 86/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5513 - accuracy: 0.0000e+00
# Epoch 87/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5511 - accuracy: 0.0000e+00
# Epoch 88/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5509 - accuracy: 0.0000e+00
# Epoch 89/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5508 - accuracy: 0.0000e+00
# Epoch 90/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5506 - accuracy: 0.0000e+00
# Epoch 91/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5504 - accuracy: 0.0000e+00
# Epoch 92/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5502 - accuracy: 0.0000e+00
# Epoch 93/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5500 - accuracy: 0.0000e+00
# Epoch 94/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5498 - accuracy: 0.0000e+00
# Epoch 95/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5496 - accuracy: 0.0000e+00
# Epoch 96/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5494 - accuracy: 0.0000e+00
# Epoch 97/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5492 - accuracy: 0.0000e+00
# Epoch 98/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5490 - accuracy: 0.0000e+00
# Epoch 99/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5489 - accuracy: 0.0000e+00
# Epoch 100/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5487 - accuracy: 0.0000e+00
# Epoch 101/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5485 - accuracy: 0.0000e+00
# Epoch 102/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5484 - accuracy: 0.0000e+00
# Epoch 103/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5482 - accuracy: 0.0000e+00
# Epoch 104/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5480 - accuracy: 0.0000e+00
# Epoch 105/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5479 - accuracy: 0.0000e+00
# Epoch 106/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5477 - accuracy: 0.0000e+00
# Epoch 107/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5475 - accuracy: 0.0000e+00
# Epoch 108/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5473 - accuracy: 0.0000e+00
# Epoch 109/200
# 30/30 [==============================] - ETA: 3s - loss: 1.9822 - accuracy: 0.0000e+ - 0s 5ms/step - loss: 1.5472 - accuracy: 0.0000e+00
# Epoch 110/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5470 - accuracy: 0.0000e+00
# Epoch 111/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5468 - accuracy: 0.0000e+00
# Epoch 112/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5467 - accuracy: 0.0000e+00
# Epoch 113/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5465 - accuracy: 0.0000e+00
# Epoch 114/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5463 - accuracy: 0.0000e+00
# Epoch 115/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5461 - accuracy: 0.0000e+00
# Epoch 116/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5460 - accuracy: 0.0000e+00
# Epoch 117/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5458 - accuracy: 0.0000e+00
# Epoch 118/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5456 - accuracy: 0.0000e+00
# Epoch 119/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5454 - accuracy: 0.0000e+00
# Epoch 120/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5452 - accuracy: 0.0000e+00
# Epoch 121/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5450 - accuracy: 0.0000e+00
# Epoch 122/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5449 - accuracy: 0.0000e+00
# Epoch 123/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5447 - accuracy: 0.0000e+00
# Epoch 124/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5445 - accuracy: 0.0000e+00
# Epoch 125/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5443 - accuracy: 0.0000e+00
# Epoch 126/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5442 - accuracy: 0.0000e+00
# Epoch 127/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5440 - accuracy: 0.0000e+00
# Epoch 128/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5438 - accuracy: 0.0000e+00
# Epoch 129/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5436 - accuracy: 0.0000e+00
# Epoch 130/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5434 - accuracy: 0.0000e+00
# Epoch 131/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5433 - accuracy: 0.0000e+00
# Epoch 132/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5431 - accuracy: 0.0000e+00
# Epoch 133/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5429 - accuracy: 0.0000e+00
# Epoch 134/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5427 - accuracy: 0.0000e+00
# Epoch 135/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5425 - accuracy: 0.0000e+00
# Epoch 136/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5423 - accuracy: 0.0000e+00
# Epoch 137/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5422 - accuracy: 0.0000e+00
# Epoch 138/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5420 - accuracy: 0.0000e+00
# Epoch 139/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5418 - accuracy: 0.0000e+00
# Epoch 140/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5416 - accuracy: 0.0000e+00
# Epoch 141/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5414 - accuracy: 0.0000e+00
# Epoch 142/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5413 - accuracy: 0.0000e+00
# Epoch 143/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5411 - accuracy: 0.0000e+00
# Epoch 144/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5409 - accuracy: 0.0000e+00
# Epoch 145/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5407 - accuracy: 0.0000e+00
# Epoch 146/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5405 - accuracy: 0.0000e+00
# Epoch 147/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5403 - accuracy: 0.0000e+00
# Epoch 148/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5401 - accuracy: 0.0000e+00
# Epoch 149/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5398 - accuracy: 0.0000e+00
# Epoch 150/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5396 - accuracy: 0.0000e+00
# Epoch 151/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5394 - accuracy: 0.0000e+00
# Epoch 152/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5392 - accuracy: 0.0000e+00
# Epoch 153/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5390 - accuracy: 0.0000e+00
# Epoch 154/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5387 - accuracy: 0.0000e+00
# Epoch 155/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5385 - accuracy: 0.0000e+00
# Epoch 156/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5383 - accuracy: 0.0000e+00
# Epoch 157/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5381 - accuracy: 0.0000e+00
# Epoch 158/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5378 - accuracy: 0.0000e+00
# Epoch 159/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5376 - accuracy: 0.0000e+00
# Epoch 160/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5374 - accuracy: 0.0000e+00
# Epoch 161/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5371 - accuracy: 0.0000e+00
# Epoch 162/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5369 - accuracy: 0.0000e+00
# Epoch 163/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5367 - accuracy: 0.0000e+00
# Epoch 164/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5364 - accuracy: 0.0000e+00
# Epoch 165/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5362 - accuracy: 0.0000e+00
# Epoch 166/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5359 - accuracy: 0.0000e+00
# Epoch 167/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5356 - accuracy: 0.0000e+00
# Epoch 168/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5354 - accuracy: 0.0000e+00
# Epoch 169/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5351 - accuracy: 0.0000e+00
# Epoch 170/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5349 - accuracy: 0.0000e+00
# Epoch 171/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5346 - accuracy: 0.0000e+00
# Epoch 172/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5344 - accuracy: 0.0000e+00
# Epoch 173/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5341 - accuracy: 0.0000e+00
# Epoch 174/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5338 - accuracy: 0.0000e+00
# Epoch 175/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5335 - accuracy: 0.0000e+00
# Epoch 176/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5332 - accuracy: 0.0000e+00
# Epoch 177/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5329 - accuracy: 0.0000e+00
# Epoch 178/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5327 - accuracy: 0.0000e+00
# Epoch 179/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5324 - accuracy: 0.0000e+00
# Epoch 180/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5322 - accuracy: 0.0000e+00
# Epoch 181/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5319 - accuracy: 0.0000e+00
# Epoch 182/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5317 - accuracy: 0.0000e+00
# Epoch 183/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5314 - accuracy: 0.0000e+00
# Epoch 184/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5312 - accuracy: 0.0000e+00
# Epoch 185/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5309 - accuracy: 0.0000e+00
# Epoch 186/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5306 - accuracy: 0.0000e+00
# Epoch 187/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5303 - accuracy: 0.0000e+00
# Epoch 188/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5300 - accuracy: 0.0000e+00
# Epoch 189/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5297 - accuracy: 0.0000e+00
# Epoch 190/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5295 - accuracy: 0.0000e+00
# Epoch 191/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5292 - accuracy: 0.0000e+00
# Epoch 192/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5289 - accuracy: 0.0000e+00
# Epoch 193/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5287 - accuracy: 0.0000e+00
# Epoch 194/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5284 - accuracy: 0.0000e+00
# Epoch 195/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5282 - accuracy: 0.0000e+00
# Epoch 196/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5280 - accuracy: 0.0000e+00
# Epoch 197/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5278 - accuracy: 0.0000e+00
# Epoch 198/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5276 - accuracy: 0.0000e+00
# Epoch 199/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5274 - accuracy: 0.0000e+00
# Epoch 200/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5272 - accuracy: 0.0000e+00

# %%
forecast = []
print ('Length of series is ',len(series))
print ('Window size is ', window_size)
for x in range(len(series)-window_size):
    forecast.append(model.predict(series[x:x+window_size][np.newaxis]))
    
# forecast is on entire series data. let's remove the data which was part of training and keep just the forecast for validation data
forecast = forecast[split_point-window_size:]
# Out:
# Length of series is  1461
# Window size is  20

# %%
results = np.array(forecast)[:,0,0]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_val, series_val)
plot_series(time_val, results)

# %%
tf.keras.metrics.mean_absolute_error(series_val, results).numpy()
# Out:
# 1.0049183

# %%
import pandas as pd

future_forecast = []
start= 1461
starting_window = series_val[-window_size:][np.newaxis]
starting_window_series = pd.Series(starting_window)

#print (starting_window)
for i in range(0, 100):    
    
    starting_window = np.array(starting_window_series)
    prediction_window = starting_window[i:window_size]    
    
    predicted_value = model.predict(prediction_window)
    print ('predicted value is ', predicted_value)
    starting_window_series.append(predicted_value)
    
    #print (starting_window)
    np.append(time_val, start+i)
    np.append(series_val, predicted_value)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-150c40f39ff1> in <module>
#       4 start= 1461
#       5 starting_window = series_val[-window_size:][np.newaxis]
# ----> 6 starting_window_series = pd.Series(starting_window)
#       7
#       8 #print (starting_window)
#
# C:\MachineLearning\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# C:\MachineLearning\anaconda\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     656     elif subarr.ndim > 1:
#     657         if isinstance(data, np.ndarray):
# --> 658             raise Exception('Data must be 1-dimensional')
#     659         else:
#     660             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional
